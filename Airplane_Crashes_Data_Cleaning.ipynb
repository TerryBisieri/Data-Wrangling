# %% [markdown]
# 1a. Upload Dataset

# %%
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-99b2d6cd-a860-493d-9b0f-252b35b606f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-99b2d6cd-a860-493d-9b0f-252b35b606f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 1b. Load the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908.csv')
df.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %% [markdown]
# 2. Size of the Dataset

# %%
rows, cols = df.shape
print(f"Number of Rows: {rows}")
print(f"Number of Columns: {cols}")
# Out:
# Number of Rows: 5268
# Number of Columns: 13

# %% [markdown]
# 3. Display Last 75 Rows

# %%
df.tail(75)
# Out:
#             Date   Time                                           Location  \
# 5193  03/15/2008  08:15                                     Nbagu, Nigeria
# 5194  04/03/2008  11:00                                     Lawa, Suriname
# 5195  04/09/2008  23:27                                Bundeena, Australia
# 5196  04/11/2008  22:15                                 Chrisinau, Moldova
# 5197  04/15/2008  14:30                                        Goma, Congo
# ...          ...    ...                                                ...
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# ...

# %% [markdown]
# 4. Missing Data Methods & Justifications

# %%
df.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1707
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %% [markdown]
# 5. Create fatality_locations

# %%
fatality_locations = df[['Date', 'Location', 'Aboard', 'Fatalities']].copy()
fatality_locations.head()
# Out:
#          Date                            Location  Aboard  Fatalities
# 0  09/17/1908                 Fort Myer, Virginia     2.0         1.0
# 1  07/12/1912             AtlantiCity, New Jersey     5.0         5.0
# 2  08/06/1913  Victoria, British Columbia, Canada     1.0         1.0
# 3  09/09/1913                  Over the North Sea    20.0        14.0
# 4  10/17/1913          Near Johannisthal, Germany    30.0        30.0

# %% [markdown]
# 6. Date of Highest Fatalities

# %%
highest_fatalities_row = fatality_locations.loc[fatality_locations['Fatalities'].idxmax()]
print("Date with highest fatalities:", highest_fatalities_row['Date'])
print("Crash details:\n", highest_fatalities_row)
# Out:
# Date with highest fatalities: 03/27/1977
# Crash details:
#  Date                        03/27/1977
# Location      Tenerife, Canary Islands
# Aboard                           644.0
# Fatalities                       583.0
# Name: 2963, dtype: object

# %% [markdown]
# 7. Passenger vs. Fatalities Comparison

# %%
zero_fatalities_count = fatality_locations[fatality_locations['Fatalities'] == 0].shape[0]
print(f"Number of recorded crashes with zero fatalities: {zero_fatalities_count}")
# Out:
# Number of recorded crashes with zero fatalities: 58

# %% [markdown]
# 8. Split Location into Region and State

# %%
split_loc = fatality_locations['Location'].str.rsplit(',', n=1, expand=True)
fatality_locations['Region'] = split_loc[0].str.strip()
fatality_locations['Country_State'] = split_loc[1].str.strip()
fatality_locations[['Location', 'Region', 'Country_State']].head()
# Out:
#                              Location                      Region  \
# 0                 Fort Myer, Virginia                   Fort Myer
# 1             AtlantiCity, New Jersey                 AtlantiCity
# 2  Victoria, British Columbia, Canada  Victoria, British Columbia
# 3                  Over the North Sea          Over the North Sea
# 4          Near Johannisthal, Germany           Near Johannisthal
#
#   Country_State
# 0      Virginia
# 1    New Jersey
# 2        Canada
# 3          None
# 4       Germany

# %% [markdown]
# 9. Order by top 100 Fatalities

# %%
top_100_fatalities = fatality_locations.sort_values(by='Fatalities', ascending=False).head(100)
top_100_fatalities.head(10)
# Out:
#             Date                                        Location  Aboard  \
# 2963  03/27/1977                        Tenerife, Canary Islands   644.0
# 3568  08/12/1985           Mt. Osutaka, near Ueno Village, Japan   524.0
# 4455  11/12/1996                        Near Charkhidadri, India   349.0
# 2726  03/03/1974                       Near Ermenonville, France   346.0
# 3562  06/23/1985         AtlantiOcean, 110 miles West of Ireland   329.0
# 3240  08/19/1980                       Near Riyadh, Saudi Arabia   301.0
# 3775  07/03/1988  Over the Persian Gulf, near Bandar Abbas, Iran   290.0
# 4916  02/19/2003                              Near Shahdad, Iran   275.0
# 3137  05/25/1979                        Chicago O'Hare, Illinois   271.0
# 3436  09/01/1983                    Near Sakhalin Island, Russia   269.0
#
#       Fatalities                                    Region  \
# 2963       583.0                                  Tenerife
# ...

# %% [markdown]
# 10. Pie Chart of Top 25 Country Fatalities

# %%
top_25_fatalities = fatality_locations.groupby('Country_State')['Fatalities'].sum().nlargest(25)
plt.figure(figsize=(12, 10))
plt.pie(top_25_fatalities, labels=top_25_fatalities.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Top 25 Fatalities by Country / U.S. State')
plt.tight_layout()
plt.show()
